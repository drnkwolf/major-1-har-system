# %%
import csv

# %%
source = 'D:/UPES/UPES SEM VII/Major 1/endsem/HAPT Data Set/AugmentedData/200feature/'
dest = 'D:/UPES/UPES SEM VII/Major 1/endsem/HAPT Data Set/FeatureSet/'

# %%
for i in range(1,13):
    target = source + str(i) + '_AugSpectroFeatures.csv'

    with open (dest+'200feature_Dataset.csv','a',newline='') as out_file:
        writer = csv.writer(out_file)
        reader = csv.reader(open(target, 'r'))
        for row in reader:
            writer.writerow(row)
