# %%
import csv
import os

# %%
def convert_csv (spath,dpath,file,check):
    with open(spath+file+'.txt', 'r') as in_file:
        with open(dpath+file+'.csv', 'w',newline='') as out_file:
            writer = csv.writer(out_file)
            z
            for line in in_file:
                lines = line.split("\n")
                lines = lines[0].split(" ")
                writer.writerow(lines)

# %%
path = 'D:/UPES/UPES SEM VII/Major 1/endsem/HAPT Data Set/RawData/'
dest = 'D:/UPES/UPES SEM VII/Major 1/endsem/HAPT Data Set/RawCSV/'
for x in os.listdir(path):
    str = x[0:3]
    if(str == "gyr"):
        convert_csv(path,dest,x[0:len(x)-4],1)
    elif(str == "acc"):
        convert_csv(path,dest,x[0:len(x)-4],0)
